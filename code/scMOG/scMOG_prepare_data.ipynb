# %% [markdown]
# ## Set path

# %%
import os
dataset_dir = os.path.join(os.getcwd(), 'datasets/')
outputs_dir = os.path.join(os.getcwd(), 'outputs/')
if not os.path.exists(outputs_dir):
    os.makedirs(outputs_dir)

save_dir = os.path.join(outputs_dir, "different samples/CITE-SLN111-Gayoso-Mouse1toMouse2/scMOG")
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %% [markdown]
# ## Load necessary libraries

# %%
import anndata
import pandas as pd

# %% [markdown]
# ## Load h5ad data

# %%
data_train = anndata.read(os.path.join(dataset_dir, "different samples/CITE-SLN111-Gayoso/Mouse1.h5ad"))
data_test = anndata.read(os.path.join(dataset_dir, "different samples/CITE-SLN111-Gayoso/Mouse2.h5ad"))
data_train, data_test
# Out:
# (AnnData object with n_obs × n_vars = 9264 × 13553
#      obs: 'n_protein_counts', 'n_proteins', 'seurat_hash_id', 'batch_indices', 'hash_id', 'n_genes', 'percent_mito', 'leiden_subclusters', 'cell_types'
#      var: 'gene_ids', 'feature_types', 'highly_variable', 'highly_variable_mean_variance', 'encode', 'hvg_encode'
#      uns: 'protein_name', 'version'
#      obsm: 'protein_expression',
#  AnnData object with n_obs × n_vars = 7564 × 13553
#      obs: 'n_protein_counts', 'n_proteins', 'seurat_hash_id', 'batch_indices', 'hash_id', 'n_genes', 'percent_mito', 'leiden_subclusters', 'cell_types'
#      var: 'gene_ids', 'feature_types', 'highly_variable', 'highly_variable_mean_variance', 'encode', 'hvg_encode'
#      uns: 'protein_name', 'version'
#      obsm: 'protein_expression')

# %% [markdown]
# ## Convert gene expression data and protein expression data to CSV format separately

# %%
rna_expression_train = pd.DataFrame(data_train.X.todense(), index=data_train.obs.index, columns=data_train.var.index).T
rna_expression_test = pd.DataFrame(data_test.X.todense(), index=data_test.obs.index, columns=data_test.var.index).T

protein_expression_train = pd.DataFrame(data_train.obsm["protein_expression"].todense(), columns=data_train.uns["protein_name"], index=data_train.obs.index).T
protein_expression_test = pd.DataFrame(data_test.obsm["protein_expression"].todense(), columns=data_test.uns["protein_name"], index=data_test.obs.index).T

rna_expression_train.to_csv(os.path.join(outputs_dir, "different samples/CITE-SLN111-Gayoso-Mouse1toMouse2/scMOG/train_gene_expression.csv"))
rna_expression_test.to_csv(os.path.join(outputs_dir, "different samples/CITE-SLN111-Gayoso-Mouse1toMouse2/scMOG/test_gene_expression.csv"))
protein_expression_train.to_csv(os.path.join(outputs_dir, "different samples/CITE-SLN111-Gayoso-Mouse1toMouse2/scMOG/train_protein_expression.csv"))
protein_expression_test.to_csv(os.path.join(outputs_dir, "different samples/CITE-SLN111-Gayoso-Mouse1toMouse2/scMOG/test_protein_expression.csv"))

rna_expression_train, rna_expression_test, protein_expression_train, protein_expression_test
# Out:
# (index          AAACCCAAGGGTAATT-1  AAACCCAAGGTAAACT-1  AAACCCACACTAGGTT-1  \
#  index
#  0610007P14Rik                 2.0                 1.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       19.0                 8.0                 3.0
#  mt-Nd4                       43.0                24.0                12.0
#  mt-Nd4l                       4.0                 1.0                 1.0
#  mt-Nd5                        5.0                 5.0                 2.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          AAACCCACAGATACCT-1  AAACCCACAGGAATAT-1  AAACCCAGTCTCACAA-1  \
#  index
#  0610007P14Rik                 0.0                 0.0                 1.0
#  0610009B22Rik                 1.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       10.0                 8.0                10.0
#  mt-Nd4                        8.0                19.0                29.0
#  mt-Nd4l                       1.0                 1.0                 0.0
#  mt-Nd5                        0.0                 2.0                12.0
#  mt-Nd6                        1.0                 0.0                 1.0
#
#  index          AAACCCATCATCGTAG-1  AAACCCATCGATACAC-1  AAACCCATCGCTAATG-1  \
#  index
#  0610007P14Rik                 1.0                 1.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                        6.0                 8.0                 3.0
#  mt-Nd4                       14.0                11.0                18.0
#  mt-Nd4l                       0.0                 3.0                 0.0
#  mt-Nd5                        3.0                 1.0                 2.0
#  mt-Nd6                        0.0                 1.0                 2.0
#
#  index          AAACCCATCTGTCAGA-1  ...  TTTGTTGCAACAAGTA-1  \
#  index                              ...
#  0610007P14Rik                 0.0  ...                 0.0
#  0610009B22Rik                 0.0  ...                 0.0
#  0610009L18Rik                 0.0  ...                 0.0
#  0610009O20Rik                 1.0  ...                 0.0
#  0610010F05Rik                 0.0  ...                 0.0
#  ...                           ...  ...                 ...
#  mt-Nd3                        3.0  ...                12.0
#  mt-Nd4                        7.0  ...                 6.0
#  mt-Nd4l                       0.0  ...                 2.0
#  mt-Nd5                        1.0  ...                 3.0
#  mt-Nd6                        0.0  ...                 0.0
#
#  index          TTTGTTGCAAGTCATC-1  TTTGTTGCAATCAAGA-1  TTTGTTGCACCCAACG-1  \
#  index
#  0610007P14Rik                 1.0                 1.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 1.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       20.0                12.0                 0.0
#  mt-Nd4                       37.0                18.0                 0.0
#  mt-Nd4l                       3.0                 1.0                 1.0
#  mt-Nd5                       13.0                 3.0                 0.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          TTTGTTGCAGGCATGA-1  TTTGTTGGTAGTCACT-1  TTTGTTGGTGGTAATA-1  \
#  index
#  0610007P14Rik                 1.0                 1.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                        4.0                 9.0                 6.0
#  mt-Nd4                        7.0                10.0                13.0
#  mt-Nd4l                       1.0                 2.0                 0.0
#  mt-Nd5                        1.0                 2.0                 4.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          TTTGTTGGTTTACGTG-1  TTTGTTGTCATGAAAG-1  TTTGTTGTCTCCGATC-1
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                        4.0                10.0                 3.0
#  mt-Nd4                        9.0                15.0                 8.0
#  mt-Nd4l                       1.0                 4.0                 0.0
#  mt-Nd5                        4.0                 5.0                 4.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  [13553 rows x 9264 columns],
#  index          AAACCCAAGAATCTAG-2  AAACCCACACCGGAAA-2  AAACCCACACTACTTT-2  \
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                        5.0                 8.0                12.0
#  mt-Nd4                        2.0                 7.0                 1.0
#  mt-Nd4l                       1.0                 6.0                 2.0
#  mt-Nd5                        1.0                 3.0                 2.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          AAACCCAGTAGGCAAC-2  AAACCCAGTCTCAGGC-2  AAACCCATCTCGTGAA-2  \
#  index
#  0610007P14Rik                 0.0                 1.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       22.0                 2.0                21.0
#  mt-Nd4                        6.0                 3.0                17.0
#  mt-Nd4l                       0.0                 1.0                 2.0
#  mt-Nd5                        2.0                 0.0                 3.0
#  mt-Nd6                        3.0                 0.0                 1.0
#
#  index          AAACGAAAGAGGTATT-2  AAACGAACAAACACCT-2  AAACGAACACCCTTAC-2  \
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       12.0                12.0                 7.0
#  mt-Nd4                        4.0                 8.0                 3.0
#  mt-Nd4l                       1.0                 2.0                 0.0
#  mt-Nd5                        2.0                 0.0                 1.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          AAACGAATCGACCTAA-2  ...  TTTGGTTTCGTCCTTG-2  \
#  index                              ...
#  0610007P14Rik                 0.0  ...                 0.0
#  0610009B22Rik                 0.0  ...                 0.0
#  0610009L18Rik                 0.0  ...                 0.0
#  0610009O20Rik                 0.0  ...                 1.0
#  0610010F05Rik                 0.0  ...                 0.0
#  ...                           ...  ...                 ...
#  mt-Nd3                       21.0  ...                 4.0
#  mt-Nd4                        6.0  ...                 5.0
#  mt-Nd4l                       2.0  ...                 5.0
#  mt-Nd5                        0.0  ...                 6.0
#  mt-Nd6                        1.0  ...                 0.0
#
#  index          TTTGTTGAGGTAGGCT-2  TTTGTTGCAGAAATCA-2  TTTGTTGCAGTTGGTT-2  \
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 1.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                        7.0                 7.0                 8.0
#  mt-Nd4                        1.0                 2.0                 2.0
#  mt-Nd4l                       1.0                 1.0                 4.0
#  mt-Nd5                        0.0                 2.0                 2.0
#  mt-Nd6                        0.0                 0.0                 1.0
#
#  index          TTTGTTGCATAGATGA-2  TTTGTTGGTAAGATCA-2  TTTGTTGGTCAGACTT-2  \
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       22.0                 8.0                11.0
#  mt-Nd4                       23.0                 4.0                 6.0
#  mt-Nd4l                       2.0                 1.0                 1.0
#  mt-Nd5                        3.0                 0.0                 2.0
#  mt-Nd6                        0.0                 0.0                 0.0
#
#  index          TTTGTTGGTGTTTACG-2  TTTGTTGTCAGAATAG-2  TTTGTTGTCGAGTGGA-2
#  index
#  0610007P14Rik                 0.0                 0.0                 0.0
#  0610009B22Rik                 0.0                 0.0                 0.0
#  0610009L18Rik                 0.0                 0.0                 0.0
#  0610009O20Rik                 0.0                 0.0                 0.0
#  0610010F05Rik                 0.0                 0.0                 0.0
#  ...                           ...                 ...                 ...
#  mt-Nd3                       14.0                 6.0                48.0
#  mt-Nd4                        7.0                 2.0                18.0
#  mt-Nd4l                       4.0                 4.0                 5.0
#  mt-Nd5                        2.0                 2.0                 4.0
#  mt-Nd6                        0.0                 0.0                 1.0
#
#  [13553 rows x 7564 columns],
#  index                             AAACCCAAGGGTAATT-1  AAACCCAAGGTAAACT-1  \
#  ADT_CD102_A0104                                 71.0                14.0
#  ADT_CD103_A0201                                  6.0                 1.0
#  ADT_CD106_A0226                                  6.0                 2.0
#  ADT_CD115(CSF-1R)_A0105                          7.0                 3.0
#  ADT_CD117(c-Kit)_A0012                           1.0                 3.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 0.0
#  ADT_Tim-4_A0567                                  9.0                 4.0
#  ADT_XCR1_A0568                                   4.0                 2.0
#  ADT_anti-P2RY12_A0415                            1.0                 4.0
#  ADT_integrinb7_A0214                            67.0                20.0
#
#  index                             AAACCCACACTAGGTT-1  AAACCCACAGATACCT-1  \
#  ADT_CD102_A0104                                 72.0                28.0
#  ADT_CD103_A0201                                  2.0                 3.0
#  ADT_CD106_A0226                                  6.0                 7.0
#  ADT_CD115(CSF-1R)_A0105                          3.0                 8.0
#  ADT_CD117(c-Kit)_A0012                           2.0                 1.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 1.0
#  ADT_Tim-4_A0567                                  7.0                 4.0
#  ADT_XCR1_A0568                                   1.0                 2.0
#  ADT_anti-P2RY12_A0415                            3.0                 2.0
#  ADT_integrinb7_A0214                             6.0                45.0
#
#  index                             AAACCCACAGGAATAT-1  AAACCCAGTCTCACAA-1  \
#  ADT_CD102_A0104                                 15.0                60.0
#  ADT_CD103_A0201                                  4.0                11.0
#  ADT_CD106_A0226                                  2.0                 6.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 2.0
#  ADT_CD117(c-Kit)_A0012                           5.0                 0.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 1.0
#  ADT_Tim-4_A0567                                 10.0                10.0
#  ADT_XCR1_A0568                                   4.0                 3.0
#  ADT_anti-P2RY12_A0415                            1.0                 4.0
#  ADT_integrinb7_A0214                            17.0                41.0
#
#  index                             AAACCCATCATCGTAG-1  AAACCCATCGATACAC-1  \
#  ADT_CD102_A0104                                 67.0                24.0
#  ADT_CD103_A0201                                 10.0                42.0
#  ADT_CD106_A0226                                  2.0                 4.0
#  ADT_CD115(CSF-1R)_A0105                          1.0                 4.0
#  ADT_CD117(c-Kit)_A0012                           4.0                 7.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 1.0
#  ADT_Tim-4_A0567                                  7.0                 7.0
#  ADT_XCR1_A0568                                   1.0                 8.0
#  ADT_anti-P2RY12_A0415                            3.0                 5.0
#  ADT_integrinb7_A0214                            49.0                83.0
#
#  index                             AAACCCATCGCTAATG-1  AAACCCATCTGTCAGA-1  ...  \
#  ADT_CD102_A0104                                 30.0                21.0  ...
#  ADT_CD103_A0201                                  1.0                 9.0  ...
#  ADT_CD106_A0226                                  3.0                 6.0  ...
#  ADT_CD115(CSF-1R)_A0105                          2.0                 3.0  ...
#  ADT_CD117(c-Kit)_A0012                           4.0                 1.0  ...
#  ...                                              ...                 ...  ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 0.0  ...
#  ADT_Tim-4_A0567                                  3.0                 4.0  ...
#  ADT_XCR1_A0568                                   2.0                 3.0  ...
#  ADT_anti-P2RY12_A0415                            4.0                 3.0  ...
#  ADT_integrinb7_A0214                            11.0                 7.0  ...
#
#  index                             TTTGTTGCAACAAGTA-1  TTTGTTGCAAGTCATC-1  \
#  ADT_CD102_A0104                                 29.0                32.0
#  ADT_CD103_A0201                                  4.0                 7.0
#  ADT_CD106_A0226                                  5.0                 2.0
#  ADT_CD115(CSF-1R)_A0105                          6.0                 1.0
#  ADT_CD117(c-Kit)_A0012                           4.0                 4.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 1.0
#  ADT_Tim-4_A0567                                  4.0                 3.0
#  ADT_XCR1_A0568                                   9.0                 2.0
#  ADT_anti-P2RY12_A0415                            1.0                 6.0
#  ADT_integrinb7_A0214                            19.0                19.0
#
#  index                             TTTGTTGCAATCAAGA-1  TTTGTTGCACCCAACG-1  \
#  ADT_CD102_A0104                                 61.0                14.0
#  ADT_CD103_A0201                                  2.0                 7.0
#  ADT_CD106_A0226                                  1.0                15.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 4.0
#  ADT_CD117(c-Kit)_A0012                           0.0                14.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 0.0
#  ADT_Tim-4_A0567                                  3.0                 9.0
#  ADT_XCR1_A0568                                   3.0                10.0
#  ADT_anti-P2RY12_A0415                            1.0                 1.0
#  ADT_integrinb7_A0214                            34.0                15.0
#
#  index                             TTTGTTGCAGGCATGA-1  TTTGTTGGTAGTCACT-1  \
#  ADT_CD102_A0104                                 21.0                16.0
#  ADT_CD103_A0201                                  3.0                 6.0
#  ADT_CD106_A0226                                  5.0                 1.0
#  ADT_CD115(CSF-1R)_A0105                          4.0                 1.0
#  ADT_CD117(c-Kit)_A0012                           9.0                 5.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 0.0
#  ADT_Tim-4_A0567                                  2.0                 2.0
#  ADT_XCR1_A0568                                   4.0                 8.0
#  ADT_anti-P2RY12_A0415                            3.0                 4.0
#  ADT_integrinb7_A0214                            22.0                24.0
#
#  index                             TTTGTTGGTGGTAATA-1  TTTGTTGGTTTACGTG-1  \
#  ADT_CD102_A0104                                 21.0                66.0
#  ADT_CD103_A0201                                  4.0                 3.0
#  ADT_CD106_A0226                                  2.0                16.0
#  ADT_CD115(CSF-1R)_A0105                          1.0                 2.0
#  ADT_CD117(c-Kit)_A0012                           2.0                 2.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 0.0
#  ADT_Tim-4_A0567                                  6.0                15.0
#  ADT_XCR1_A0568                                   5.0                 2.0
#  ADT_anti-P2RY12_A0415                            6.0                 7.0
#  ADT_integrinb7_A0214                            37.0                23.0
#
#  index                             TTTGTTGTCATGAAAG-1  TTTGTTGTCTCCGATC-1
#  ADT_CD102_A0104                                 26.0                20.0
#  ADT_CD103_A0201                                 11.0                 2.0
#  ADT_CD106_A0226                                  4.0                 1.0
#  ADT_CD115(CSF-1R)_A0105                          1.0                 4.0
#  ADT_CD117(c-Kit)_A0012                           8.0                 5.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                  2.0                 4.0
#  ADT_XCR1_A0568                                   1.0                 1.0
#  ADT_anti-P2RY12_A0415                            2.0                 2.0
#  ADT_integrinb7_A0214                            14.0                11.0
#
#  [110 rows x 9264 columns],
#  index                             AAACCCAAGAATCTAG-2  AAACCCACACCGGAAA-2  \
#  ADT_CD102_A0104                                 65.0                73.0
#  ADT_CD103_A0201                                  5.0                 4.0
#  ADT_CD106_A0226                                  3.0                 4.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 2.0
#  ADT_CD117(c-Kit)_A0012                           2.0                 2.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 0.0                 1.0
#  ADT_Tim-4_A0567                                  8.0                 5.0
#  ADT_XCR1_A0568                                   2.0                 1.0
#  ADT_anti-P2RY12_A0415                            3.0                 4.0
#  ADT_integrinb7_A0214                            31.0                12.0
#
#  index                             AAACCCACACTACTTT-2  AAACCCAGTAGGCAAC-2  \
#  ADT_CD102_A0104                                 45.0                78.0
#  ADT_CD103_A0201                                  6.0                 9.0
#  ADT_CD106_A0226                                  3.0                11.0
#  ADT_CD115(CSF-1R)_A0105                          3.0                 1.0
#  ADT_CD117(c-Kit)_A0012                           3.0                 2.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                  4.0                 5.0
#  ADT_XCR1_A0568                                   5.0                 6.0
#  ADT_anti-P2RY12_A0415                            3.0                 4.0
#  ADT_integrinb7_A0214                            42.0                14.0
#
#  index                             AAACCCAGTCTCAGGC-2  AAACCCATCTCGTGAA-2  \
#  ADT_CD102_A0104                                 64.0                58.0
#  ADT_CD103_A0201                                  3.0                 3.0
#  ADT_CD106_A0226                                  5.0                 3.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 5.0
#  ADT_CD117(c-Kit)_A0012                           2.0                 6.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                  0.0                 6.0
#  ADT_XCR1_A0568                                   0.0                 2.0
#  ADT_anti-P2RY12_A0415                            8.0                 1.0
#  ADT_integrinb7_A0214                            33.0                71.0
#
#  index                             AAACGAAAGAGGTATT-2  AAACGAACAAACACCT-2  \
#  ADT_CD102_A0104                                 64.0                14.0
#  ADT_CD103_A0201                                  3.0                 4.0
#  ADT_CD106_A0226                                  4.0                 3.0
#  ADT_CD115(CSF-1R)_A0105                          3.0                 1.0
#  ADT_CD117(c-Kit)_A0012                           3.0                 8.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 2.0                 1.0
#  ADT_Tim-4_A0567                                  9.0                 5.0
#  ADT_XCR1_A0568                                   6.0                 3.0
#  ADT_anti-P2RY12_A0415                            2.0                 2.0
#  ADT_integrinb7_A0214                            46.0                24.0
#
#  index                             AAACGAACACCCTTAC-2  AAACGAATCGACCTAA-2  ...  \
#  ADT_CD102_A0104                                 63.0                61.0  ...
#  ADT_CD103_A0201                                  5.0                 3.0  ...
#  ADT_CD106_A0226                                  3.0                 7.0  ...
#  ADT_CD115(CSF-1R)_A0105                          2.0                 0.0  ...
#  ADT_CD117(c-Kit)_A0012                           1.0                 2.0  ...
#  ...                                              ...                 ...  ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0  ...
#  ADT_Tim-4_A0567                                  3.0                 7.0  ...
#  ADT_XCR1_A0568                                   2.0                 3.0  ...
#  ADT_anti-P2RY12_A0415                            3.0                 5.0  ...
#  ADT_integrinb7_A0214                            39.0                55.0  ...
#
#  index                             TTTGGTTTCGTCCTTG-2  TTTGTTGAGGTAGGCT-2  \
#  ADT_CD102_A0104                                 64.0                98.0
#  ADT_CD103_A0201                                  3.0                 1.0
#  ADT_CD106_A0226                                 38.0                 3.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 6.0
#  ADT_CD117(c-Kit)_A0012                           2.0                 5.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                  3.0                 5.0
#  ADT_XCR1_A0568                                   8.0                 1.0
#  ADT_anti-P2RY12_A0415                            7.0                 4.0
#  ADT_integrinb7_A0214                            52.0                21.0
#
#  index                             TTTGTTGCAGAAATCA-2  TTTGTTGCAGTTGGTT-2  \
#  ADT_CD102_A0104                                 49.0                41.0
#  ADT_CD103_A0201                                  4.0                 1.0
#  ADT_CD106_A0226                                  5.0                 3.0
#  ADT_CD115(CSF-1R)_A0105                          1.0                 4.0
#  ADT_CD117(c-Kit)_A0012                           1.0                 2.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                  4.0                 5.0
#  ADT_XCR1_A0568                                   3.0                 3.0
#  ADT_anti-P2RY12_A0415                            3.0                 0.0
#  ADT_integrinb7_A0214                            46.0                30.0
#
#  index                             TTTGTTGCATAGATGA-2  TTTGTTGGTAAGATCA-2  \
#  ADT_CD102_A0104                                 20.0                52.0
#  ADT_CD103_A0201                                  3.0                 2.0
#  ADT_CD106_A0226                                 95.0                 5.0
#  ADT_CD115(CSF-1R)_A0105                          9.0                 2.0
#  ADT_CD117(c-Kit)_A0012                           5.0                 4.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 1.0
#  ADT_Tim-4_A0567                                104.0                 1.0
#  ADT_XCR1_A0568                                   4.0                 1.0
#  ADT_anti-P2RY12_A0415                            3.0                 3.0
#  ADT_integrinb7_A0214                            13.0                29.0
#
#  index                             TTTGTTGGTCAGACTT-2  TTTGTTGGTGTTTACG-2  \
#  ADT_CD102_A0104                                 45.0               124.0
#  ADT_CD103_A0201                                  8.0                 2.0
#  ADT_CD106_A0226                                  0.0                 6.0
#  ADT_CD115(CSF-1R)_A0105                          2.0                 1.0
#  ADT_CD117(c-Kit)_A0012                           3.0                 3.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 2.0
#  ADT_Tim-4_A0567                                  4.0                 5.0
#  ADT_XCR1_A0568                                   7.0                 1.0
#  ADT_anti-P2RY12_A0415                            3.0                 3.0
#  ADT_integrinb7_A0214                            28.0                 8.0
#
#  index                             TTTGTTGTCAGAATAG-2  TTTGTTGTCGAGTGGA-2
#  ADT_CD102_A0104                                 30.0                73.0
#  ADT_CD103_A0201                                  9.0                 2.0
#  ADT_CD106_A0226                                  6.0                 5.0
#  ADT_CD115(CSF-1R)_A0105                          7.0                 2.0
#  ADT_CD117(c-Kit)_A0012                           1.0                 9.0
#  ...                                              ...                 ...
#  ADT_TER-119-ErythroidCells_A0122                 1.0                 0.0
#  ADT_Tim-4_A0567                                  5.0                 6.0
#  ADT_XCR1_A0568                                   6.0                 1.0
#  ADT_anti-P2RY12_A0415                            4.0                 2.0
#  ADT_integrinb7_A0214                            27.0                39.0
#
#  [110 rows x 7564 columns])
